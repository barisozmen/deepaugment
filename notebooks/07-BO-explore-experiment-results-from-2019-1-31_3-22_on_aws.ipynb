# %%
EXPERIMENT_NOTEBOOK_PATH = "../reports/experiments/2019-1-31_3-22_on_aws/notebook.csv"

# %%
import os
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
exp_df = pd.read_csv(EXPERIMENT_NOTEBOOK_PATH)
exp_df.head()
# Out:
#      acc      loss  val_acc  val_loss  trial_no aug_type magnitude  sample_no  \
# 0  0.114  2.300610    0.092  2.298126         0        -         -          1
# 1  0.131  2.287915    0.126  2.288309         0        -         -          1
# 2  0.162  2.269498    0.187  2.265500         0        -         -          1
# 3  0.182  2.236111    0.197  2.222181         0        -         -          1
# 4  0.209  2.177493    0.219  2.138166         0        -         -          1
#
#    mean_late_val_acc
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
exp_df
# Out:
#          acc      loss  val_acc  val_loss  trial_no aug_type  \
# 0     0.1140  2.300610    0.092  2.298126         0        -
# 1     0.1310  2.287915    0.126  2.288309         0        -
# 2     0.1620  2.269498    0.187  2.265500         0        -
# 3     0.1820  2.236111    0.197  2.222181         0        -
# 4     0.2090  2.177493    0.219  2.138166         0        -
# 5     0.2320  2.106411    0.277  2.052048         0        -
# 6     0.2590  2.018313    0.272  2.024832         0        -
# 7     0.2890  1.977730    0.311  1.930946         0        -
# 8     0.2940  1.933335    0.257  2.003644         0        -
# 9     0.2960  1.910088    0.283  1.942959         0        -
# 10    0.3090  1.876710    0.321  1.891637         0        -
# 11    0.3300  1.858039    0.260  2.059113         0        -
# 12    0.3310  1.835342    0.322  1.877988         0        -
# 13    0.3390  1.810035    0.332  1.841143         0        -
# 14    0.3340  1.799928    0.330  1.852758         0        -
# 15    0.3590  1.764199    0.352  1.802699         0        -
# 16    0.3500  1.748876    0.344  1.790698         0        -
# 17    0.3430  1.745904    0.366  1.782894         0        -
# 18    0.3720  1.737315    0.339  1.809097         0        -
# 19    0.3830  1.715770    0.346  1.782176         0        -
# 20    0.3350  1.836875    0.361  1.790177         1        5
# 21    0.3790  1.762784    0.371  1.761266         1        5
# 22    0.3945  1.705722    0.367  1.751420         1        5
# 23    0.4030  1.683783    0.372  1.760726         1        5
# 24    0.4035  1.661104    0.367  1.728366         1        5
# 25    0.4050  1.641826    0.353  1.789692         1        5
# 26    0.4345  1.612492    0.361  1.713897         1        5
# 27    0.4360  1.586175    0.360  1.750517         1        5
# 28    0.4470  1.564423    0.373  1.703739         1        5
# 29    0.4425  1.528796    0.375  1.703692         1        5
# ...      ...       ...      ...       ...       ...      ...
# 2490  0.4070  1.636898    0.377  1.725727        25        7
# 2491  0.4110  1.635740    0.377  1.731920        25        7
# 2492  0.4100  1.611102    0.386  1.708734        25        7
# 2493  0.4310  1.593969    0.345  1.744846        25        7
# 2494  0.4405  1.581758    0.378  1.719991        25        7
# 2495  0.4335  1.555809    0.381  1.686041        25        7
# 2496  0.4495  1.553767    0.369  1.745030        25        7
# 2497  0.4505  1.535256    0.380  1.695389        25        7
# 2498  0.4530  1.512964    0.390  1.713645        25        7
# 2499  0.4615  1.485709    0.366  1.708323        25        7
# 2500  0.2920  2.067366    0.341  1.851506        25        7
# 2501  0.3405  1.851754    0.344  1.810989        25        7
# 2502  0.3360  1.838023    0.341  1.797326        25        7
# 2503  0.3590  1.796630    0.350  1.783540        25        7
# 2504  0.3610  1.770112    0.348  1.764254        25        7
# 2505  0.3795  1.732890    0.343  1.776479        25        7
# 2506  0.3780  1.726957    0.355  1.771659        25        7
# 2507  0.3805  1.709980    0.361  1.745803        25        7
# 2508  0.3930  1.674325    0.368  1.750176        25        7
# 2509  0.4035  1.662120    0.372  1.721804        25        7
# 2510  0.4135  1.643674    0.367  1.739823        25        7
# 2511  0.4015  1.624043    0.347  1.837338        25        7
# 2512  0.4190  1.620280    0.374  1.710072        25        7
# 2513  0.4240  1.586811    0.378  1.696637        25        7
# 2514  0.4395  1.572970    0.368  1.719851        25        7
# 2515  0.4440  1.563734    0.358  1.745800        25        7
# 2516  0.4295  1.558140    0.384  1.718334        25        7
# 2517  0.4620  1.514687    0.382  1.707217        25        7
# 2518  0.4740  1.500737    0.385  1.701051        25        7
# 2519  0.4790  1.484167    0.378  1.701035        25        7
#
#                magnitude  sample_no  mean_late_val_acc
# 0                      -          1                NaN
# 1                      -          1                NaN
# 2                      -          1                NaN
# 3                      -          1                NaN
# 4                      -          1                NaN
# 5                      -          1                NaN
# 6                      -          1                NaN
# 7                      -          1                NaN
# 8                      -          1                NaN
# 9                      -          1                NaN
# 10                     -          1                NaN
# 11                     -          1                NaN
# 12                     -          1                NaN
# 13                     -          1                NaN
# 14                     -          1                NaN
# 15                     -          1                NaN
# 16                     -          1                NaN
# 17                     -          1                NaN
# 18                     -          1                NaN
# 19                     -          1                NaN
# 20    0.8442657485810175          1             0.3838
# 21    0.8442657485810175          1             0.3838
# 22    0.8442657485810175          1             0.3838
# 23    0.8442657485810175          1             0.3838
# 24    0.8442657485810175          1             0.3838
# 25    0.8442657485810175          1             0.3838
# 26    0.8442657485810175          1             0.3838
# 27    0.8442657485810175          1             0.3838
# 28    0.8442657485810175          1             0.3838
# 29    0.8442657485810175          1             0.3838
# ...                  ...        ...                ...
# 2490  0.8359685936118062          4             0.3772
# 2491  0.8359685936118062          4             0.3772
# 2492  0.8359685936118062          4             0.3772
# 2493  0.8359685936118062          4             0.3772
# 2494  0.8359685936118062          4             0.3772
# 2495  0.8359685936118062          4             0.3772
# 2496  0.8359685936118062          4             0.3772
# 2497  0.8359685936118062          4             0.3772
# 2498  0.8359685936118062          4             0.3772
# 2499  0.8359685936118062          4             0.3772
# 2500  0.8359685936118062          5             0.3774
# 2501  0.8359685936118062          5             0.3774
# 2502  0.8359685936118062          5             0.3774
# 2503  0.8359685936118062          5             0.3774
# 2504  0.8359685936118062          5             0.3774
# 2505  0.8359685936118062          5             0.3774
# 2506  0.8359685936118062          5             0.3774
# 2507  0.8359685936118062          5             0.3774
# 2508  0.8359685936118062          5             0.3774
# 2509  0.8359685936118062          5             0.3774
# 2510  0.8359685936118062          5             0.3774
# 2511  0.8359685936118062          5             0.3774
# 2512  0.8359685936118062          5             0.3774
# 2513  0.8359685936118062          5             0.3774
# 2514  0.8359685936118062          5             0.3774
# 2515  0.8359685936118062          5             0.3774
# 2516  0.8359685936118062          5             0.3774
# 2517  0.8359685936118062          5             0.3774
# 2518  0.8359685936118062          5             0.3774
# 2519  0.8359685936118062          5             0.3774
#
# [2520 rows x 9 columns]

# %%
color_palette = ["red","blue","chocolate","salmon","green","pink","orange",
                 "purple","magenta","sienna","teal","khaki","yellow","darkgreen",
                 "darkblue", "cyan","tan","yellowgreen","tomato","olive",
                 "navy","ivory","brown","azure", '#e6194b', '#3cb44b', '#ffe119', '#4363d8', 
                 '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', 
                 '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', 
                 '#000075', '#808080', '#ffffff', '#000000']

def plot_exp_lines(monitor_col="val_loss"):
    
    rowList = []
    
    for exp_id in exp_df["trial_no"].unique():
        
        iter_df = exp_df[exp_df["trial_no"]==exp_id].copy()

        
        exp_color = color_palette[exp_id]
        
        if exp_df[exp_df["trial_no"]==exp_id]["magnitude"].values[0]==0.0:
            exp_color="black"
        
        mean_last_scores = []
        
        for sample_id in iter_df["sample_no"].unique():
            sample_df = iter_df[iter_df["sample_no"]==sample_id].copy()
            xs = np.arange(1,21,1)
            plt.plot(xs, sample_df[monitor_col], color=exp_color, alpha=0.5, linewidth=2)
            
            mean_last_scores.append(sample_df[monitor_col].tail(3).mean())
            
        plt.title(monitor_col)
            
        score = np.mean(mean_last_scores)
        param1 = iter_df["aug_type"].values[0]
        param2 = iter_df["magnitude"].values[0]
        
        rowList.append([param1,param2,score])
        
    ret_df = pd.DataFrame(rowList, columns=["aug_type","magnitude","mean_last_"+monitor_col]) 
    return ret_df.sort_values("mean_last_"+monitor_col, ascending=False)

# %%
plot_exp_lines("val_acc")
# Out:
#    aug_type             magnitude  mean_last_val_acc
# 4         3  0.056712977317443194           0.400867
# 5         3      0.47766511732135           0.398200
# 15        7  0.009331418951692318           0.397133
# 12        1    0.5791635279602427           0.396200
# 24        2    0.8011909894732967           0.395200
# 7         5    0.8762915987832829           0.394733
# 13        7   0.11863057508791722           0.394200
# 1         5    0.8442657485810175           0.392533
# 17        3    0.5452317150779727           0.392533
# 19        7    0.2025121138976455           0.392000
# 10        7    0.2802448208524437           0.390733
# 20        7   0.16857964701848763           0.389800
# 9         7    0.5145057243034092           0.389467
# 21        7    0.1895239507134317           0.388200
# 16        7   0.29464950204564194           0.385933
# 3         5   0.38438170729269994           0.384867
# 11        7     0.542553733581784           0.384733
# 18        7    0.5769838527152508           0.384533
# 14        7    0.2886581352483401           0.384333
# 2         7    0.8472517387841256           0.384000
# 25        7    0.8359685936118062           0.383400
# 23        7    0.7989004129581073           0.382733
# 6         7    0.5451576858874873           0.381467
# 8         7    0.6077663562209804           0.380067
# 22        7    0.9835311605626481           0.376733
# 0         -                     -           0.350333

# %%
plot_exp_lines("val_loss")
# Out:
#    aug_type             magnitude  mean_last_val_loss
# 0         -                     -            1.791389
# 11        7     0.542553733581784            1.723960
# 8         7    0.6077663562209804            1.723739
# 22        7    0.9835311605626481            1.723704
# 18        7    0.5769838527152508            1.718796
# 9         7    0.5145057243034092            1.716686
# 16        7   0.29464950204564194            1.715215
# 3         5   0.38438170729269994            1.714654
# 6         7    0.5451576858874873            1.714513
# 24        2    0.8011909894732967            1.713775
# 14        7    0.2886581352483401            1.711111
# 2         7    0.8472517387841256            1.711053
# 23        7    0.7989004129581073            1.708045
# 25        7    0.8359685936118062            1.706333
# 4         3  0.056712977317443194            1.701739
# 10        7    0.2802448208524437            1.699000
# 21        7    0.1895239507134317            1.697866
# 13        7   0.11863057508791722            1.694375
# 15        7  0.009331418951692318            1.694003
# 19        7    0.2025121138976455            1.692049
# 20        7   0.16857964701848763            1.690911
# 1         5    0.8442657485810175            1.687255
# 12        1    0.5791635279602427            1.683774
# 7         5    0.8762915987832829            1.679650
# 17        3    0.5452317150779727            1.676483
# 5         3      0.47766511732135            1.671383
